# %%
import os
kk={}
a = open("data_file_color.txt", "w")
b = open("data_file_thermal.txt", "w")
counter=1
cc=0
for path, subdirs, files in os.walk(r'/Users/ayush/projects/Visible-Thermal-Person-Re-Identification-master/BDTR/data_trial/test'):
    for filename in files:
        #print(filename)
        cc+=1
        f = os.path.join(path, filename)
        label_file = f.split('/')[-1]
        label_file=label_file.split('.')[0]
        print(label_file)
        k=label_file.split('_')
        print(k)
        label=k[0]+"_"+k[2]
        if label not in kk:
            kk[label]=counter
            counter+=1
        text_label =kk[label]   
        #print(label)
        a.write(str(f) +" "+ str(text_label)+ os.linesep) 
        b.write(str(f) +" "+ str(text_label)+ os.linesep)
# Out:
# 7_blur1_2
# ['7', 'blur1', '2']
# 6_blur1_2_copy
# ['6', 'blur1', '2', 'copy']
# 4_blur4_1
# ['4', 'blur4', '1']
# 6_blur1_3_copy
# ['6', 'blur1', '3', 'copy']
# 5_actual_1_copy
# ['5', 'actual', '1', 'copy']
# 7_blur3_2_copy
# ['7', 'blur3', '2', 'copy']
# 7_blur3_3_copy
# ['7', 'blur3', '3', 'copy']
# 5_surface_2_copy
# ['5', 'surface', '2', 'copy']
# 5_surface_3_copy
# ['5', 'surface', '3', 'copy']
# 4_blur5_3_copy
# ['4', 'blur5', '3', 'copy']
# 4_blur5_2_copy
# ['4', 'blur5', '2', 'copy']
# 7_blur3_1
# ['7', 'blur3', '1']
# 5_actual_4
# ['5', 'actual', '4']
# 7_blur1_3
# ['7', 'blur1', '3']
# 7_blur1_1
# ['7', 'blur1', '1']
# 4_blur4_2
# ['4', 'blur4', '2']
# 7_blur3_3
# ['7', 'blur3', '3']
# 7_blur2_1_copy
# ['7', 'blur2', '1', 'copy']
# 5_blur0_4_copy
# ['5', 'blur0', '4', 'copy']
# 6_blur0_1_copy
# ['6', 'blur0', '1', 'copy']
# 4_blur4_1_copy
# ['4', 'blur4', '1', 'copy']
# 7_blur3_2
# ['7', 'blur3', '2']
# 4_blur4_3
# ['4', 'blur4', '3']
# 6_blur5_1_copy
# ['6', 'blur5', '1', 'copy']
# 5_blur5_4_copy
# ['5', 'blur5', '4', 'copy']
# 7_blur1_4
# ['7', 'blur1', '4']
# 5_actual_3
# ['5', 'actual', '3']
# 6_blur3_4_copy
# ['6', 'blur3', '4', 'copy']
# 5_blur3_1_copy
# ['5', 'blur3', '1', 'copy']
# 7_blur1_4_copy
# ['7', 'blur1', '4', 'copy']
# 5_actual_2
# ['5', 'actual', '2']
# 4_blur4_4
# ['4', 'blur4', '4']
# 6_surface_3_copy
# ['6', 'surface', '3', 'copy']
# 6_surface_2_copy
# ['6', 'surface', '2', 'copy']
# 6_blur4_2_copy
# ['6', 'blur4', '2', 'copy']
# 6_blur4_3_copy
# ['6', 'blur4', '3', 'copy']
# 7_blur3_4
# ['7', 'blur3', '4']
# 5_actual_1
# ['5', 'actual', '1']
# 5_blur2_3_copy
# ['5', 'blur2', '3', 'copy']
# 5_blur2_2_copy
# ['5', 'blur2', '2', 'copy']
# 4_blur3_4
# ['4', 'blur3', '4']
# 5_blur5_2_copy
# ['5', 'blur5', '2', 'copy']
# 5_blur5_3_copy
# ['5', 'blur5', '3', 'copy']
# 7_actual_1_copy
# ['7', 'actual', '1', 'copy']
# 5_surface_2
# ['5', 'surface', '2']
# 7_blur2_3
# ['7', 'blur2', '3']
# 7_blur0_1
# ['7', 'blur0', '1']
# 4_blur5_2
# ['4', 'blur5', '2']
# 6_blur3_3_copy
# ['6', 'blur3', '3', 'copy']
# 6_blur3_2_copy
# ['6', 'blur3', '2', 'copy']
# 4_blur5_3
# ['4', 'blur5', '3']
# 7_blur2_2
# ['7', 'blur2', '2']
# 5_surface_3
# ['5', 'surface', '3']
# 7_blur1_3_copy
# ['7', 'blur1', '3', 'copy']
# 7_blur1_2_copy
# ['7', 'blur1', '2', 'copy']
# 6_surface_4
# ['6', 'surface', '4']
# 6_surface_4_copy
# ['6', 'surface', '4', 'copy']
# 4_surface_1_copy
# ['4', 'surface', '1', 'copy']
# 5_surface_1
# ['5', 'surface', '1']
# 7_blur0_2
# ['7', 'blur0', '2']
# 4_blur5_1
# ['4', 'blur5', '1']
# 6_blur4_4_copy
# ['6', 'blur4', '4', 'copy']
# 5_blur4_1_copy
# ['5', 'blur4', '1', 'copy']
# 7_blur0_3
# ['7', 'blur0', '3']
# 7_blur0_1_copy
# ['7', 'blur0', '1', 'copy']
# 7_blur2_1
# ['7', 'blur2', '1']
# 6_blur2_1_copy
# ['6', 'blur2', '1', 'copy']
# 5_blur2_4_copy
# ['5', 'blur2', '4', 'copy']
# 4_blur3_2
# ['4', 'blur3', '2']
# 6_surface_1
# ['6', 'surface', '1']
# 5_blur1_1_copy
# ['5', 'blur1', '1', 'copy']
# 6_blur1_4_copy
# ['6', 'blur1', '4', 'copy']
# 5_surface_4
# ['5', 'surface', '4']
# 6_actual_1_copy
# ['6', 'actual', '1', 'copy']
# 7_blur3_4_copy
# ['7', 'blur3', '4', 'copy']
# 4_blur5_4
# ['4', 'blur5', '4']
# 7_blur2_4
# ['7', 'blur2', '4']
# 5_surface_4_copy
# ['5', 'surface', '4', 'copy']
# 4_blur5_4_copy
# ['4', 'blur5', '4', 'copy']
# 4_blur3_3
# ['4', 'blur3', '3']
# 6_surface_2
# ['6', 'surface', '2']
# 7_blur0_4
# ['7', 'blur0', '4']
# 5_blur0_2_copy
# ['5', 'blur0', '2', 'copy']
# 5_blur0_3_copy
# ['5', 'blur0', '3', 'copy']
# 7_blur4_1
# ['7', 'blur4', '1']
# 6_surface_3
# ['6', 'surface', '3']
# 5_blur0_1
# ['5', 'blur0', '1']
# 6_blur5_2
# ['6', 'blur5', '2']
# 5_blur2_3
# ['5', 'blur2', '3']
# 6_surface_1_copy
# ['6', 'surface', '1', 'copy']
# 4_surface_4_copy
# ['4', 'surface', '4', 'copy']
# 5_blur4_4_copy
# ['5', 'blur4', '4', 'copy']
# 6_blur4_1_copy
# ['6', 'blur4', '1', 'copy']
# 6_blur3_4
# ['6', 'blur3', '4']
# 7_blur0_4_copy
# ['7', 'blur0', '4', 'copy']
# 5_blur4_4
# ['5', 'blur4', '4']
# 4_surface_4
# ['4', 'surface', '4']
# 5_blur2_2
# ['5', 'blur2', '2']
# 5_blur2_1_copy
# ['5', 'blur2', '1', 'copy']
# 6_blur2_4_copy
# ['6', 'blur2', '4', 'copy']
# 6_blur5_3
# ['6', 'blur5', '3']
# 5_blur0_2
# ['5', 'blur0', '2']
# 7_actual_4_copy
# ['7', 'actual', '4', 'copy']
# 6_blur5_1
# ['6', 'blur5', '1']
# 6_blur5_3_copy
# ['6', 'blur5', '3', 'copy']
# 6_blur5_2_copy
# ['6', 'blur5', '2', 'copy']
# 5_blur3_2_copy
# ['5', 'blur3', '2', 'copy']
# 5_blur3_3_copy
# ['5', 'blur3', '3', 'copy']
# 6_blur1_4
# ['6', 'blur1', '4']
# 5_blur2_1
# ['5', 'blur2', '1']
# 5_blur0_3
# ['5', 'blur0', '3']
# 6_blur5_4
# ['6', 'blur5', '4']
# 4_surface_3
# ['4', 'surface', '3']
# 7_blur2_3_copy
# ['7', 'blur2', '3', 'copy']
# 7_blur2_2_copy
# ['7', 'blur2', '2', 'copy']
# 6_blur0_3_copy
# ['6', 'blur0', '3', 'copy']
# 5_blur4_3
# ['5', 'blur4', '3']
# 6_blur0_2_copy
# ['6', 'blur0', '2', 'copy']
# 6_blur3_2
# ['6', 'blur3', '2']
# 4_blur4_2_copy
# ['4', 'blur4', '2', 'copy']
# 4_blur4_3_copy
# ['4', 'blur4', '3', 'copy']
# 6_blur3_3
# ['6', 'blur3', '3']
# 5_blur4_2
# ['5', 'blur4', '2']
# 6_blur1_1
# ['6', 'blur1', '1']
# 5_blur2_4
# ['5', 'blur2', '4']
# 4_surface_2
# ['4', 'surface', '2']
# 6_actual_4_copy
# ['6', 'actual', '4', 'copy']
# 5_blur0_4
# ['5', 'blur0', '4']
# 6_blur1_1_copy
# ['6', 'blur1', '1', 'copy']
# 5_blur1_4_copy
# ['5', 'blur1', '4', 'copy']
# 5_actual_3_copy
# ['5', 'actual', '3', 'copy']
# 5_actual_2_copy
# ['5', 'actual', '2', 'copy']
# 6_blur1_3
# ['6', 'blur1', '3']
# 6_blur3_1
# ['6', 'blur3', '1']
# 4_blur3_4_copy
# ['4', 'blur3', '4', 'copy']
# 7_blur3_1_copy
# ['7', 'blur3', '1', 'copy']
# 5_surface_1_copy
# ['5', 'surface', '1', 'copy']
# 5_blur4_1
# ['5', 'blur4', '1']
# 6_blur1_2
# ['6', 'blur1', '2']
# 4_blur5_1_copy
# ['4', 'blur5', '1', 'copy']
# 4_surface_1
# ['4', 'surface', '1']
# 7_blur2_4_copy
# ['7', 'blur2', '4', 'copy']
# 6_actual_4
# ['6', 'actual', '4']
# 5_blur1_2
# ['5', 'blur1', '2']
# 6_blur0_4_copy
# ['6', 'blur0', '4', 'copy']
# 5_blur0_1_copy
# ['5', 'blur0', '1', 'copy']
# 6_blur4_1
# ['6', 'blur4', '1']
# 7_actual_3
# ['7', 'actual', '3']
# 7_actual_2
# ['7', 'actual', '2']
# 5_blur1_3
# ['5', 'blur1', '3']
# 4_blur4_4_copy
# ['4', 'blur4', '4', 'copy']
# 7_blur4_1_copy
# ['7', 'blur4', '1', 'copy']
# 5_blur3_1
# ['5', 'blur3', '1']
# 6_blur0_4
# ['6', 'blur0', '4']
# 6_blur2_4
# ['6', 'blur2', '4']
# 5_actual_4_copy
# ['5', 'actual', '4', 'copy']
# 6_actual_3_copy
# ['6', 'actual', '3', 'copy']
# 6_actual_2_copy
# ['6', 'actual', '2', 'copy']
# 5_blur1_3_copy
# ['5', 'blur1', '3', 'copy']
# 5_blur1_2_copy
# ['5', 'blur1', '2', 'copy']
# 5_blur3_3
# ['5', 'blur3', '3']
# 4_blur3_3_copy
# ['4', 'blur3', '3', 'copy']
# 4_blur3_2_copy
# ['4', 'blur3', '2', 'copy']
# 5_blur1_1
# ['5', 'blur1', '1']
# 6_blur4_2
# ['6', 'blur4', '2']
# 7_actual_1
# ['7', 'actual', '1']
# 6_blur4_3
# ['6', 'blur4', '3']
# 5_blur3_2
# ['5', 'blur3', '2']
# 5_blur5_4
# ['5', 'blur5', '4']
# 4_surface_2_copy
# ['4', 'surface', '2', 'copy']
# 6_blur2_1
# ['6', 'blur2', '1']
# 4_surface_3_copy
# ['4', 'surface', '3', 'copy']
# 6_actual_2
# ['6', 'actual', '2']
# 6_blur0_3
# ['6', 'blur0', '3']
# 5_blur4_3_copy
# ['5', 'blur4', '3', 'copy']
# 5_blur4_2_copy
# ['5', 'blur4', '2', 'copy']
# 5_blur1_4
# ['5', 'blur1', '4']
# 7_actual_4
# ['7', 'actual', '4']
# 7_blur0_2_copy
# ['7', 'blur0', '2', 'copy']
# 7_blur0_3_copy
# ['7', 'blur0', '3', 'copy']
# 6_blur2_2_copy
# ['6', 'blur2', '2', 'copy']
# 6_blur2_3_copy
# ['6', 'blur2', '3', 'copy']
# 5_blur5_1
# ['5', 'blur5', '1']
# 6_actual_3
# ['6', 'actual', '3']
# 6_blur0_2
# ['6', 'blur0', '2']
# 6_blur2_2
# ['6', 'blur2', '2']
# 6_actual_1
# ['6', 'actual', '1']
# 7_actual_2_copy
# ['7', 'actual', '2', 'copy']
# 7_actual_3_copy
# ['7', 'actual', '3', 'copy']
# 5_blur5_3
# ['5', 'blur5', '3']
# 5_blur5_1_copy
# ['5', 'blur5', '1', 'copy']
# 6_blur5_4_copy
# ['6', 'blur5', '4', 'copy']
# 6_blur4_4
# ['6', 'blur4', '4']
# 5_blur3_4_copy
# ['5', 'blur3', '4', 'copy']
# 6_blur3_1_copy
# ['6', 'blur3', '1', 'copy']
# 5_blur3_4
# ['5', 'blur3', '4']
# 5_blur5_2
# ['5', 'blur5', '2']
# 6_blur0_1
# ['6', 'blur0', '1']
# 7_blur1_1_copy
# ['7', 'blur1', '1', 'copy']
# 6_blur2_3
# ['6', 'blur2', '3']

# %%
len(kk)
print(cc)
# Out:
# 200

# %%
# !rm /Users/ayush/projects/Visible-Thermal-Person-Re-Identification-master/BDTR/data_trial/test/.DS_Store

# %%
# !pip install tensorflow==1.11.0
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow==1.11.0 (from versions: 1.13.0rc1, 1.13.0rc2, 1.13.1, 1.13.2, 1.14.0rc0, 1.14.0rc1, 1.14.0, 1.15.0rc0, 1.15.0rc1, 1.15.0rc2, 1.15.0rc3, 1.15.0, 2.0.0a0, 2.0.0b0, 2.0.0b1, 2.0.0rc0, 2.0.0rc1, 2.0.0rc2, 2.0.0, 2.1.0rc0, 2.1.0rc1, 2.1.0rc2)
# ERROR: No matching distribution found for tensorflow==1.11.0

# %%
import numpy as np
print(np.__version__)
# Out:
# 1.16.2

# %%
import tensorflow as tf
# Out:
# /Users/ayush/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.6 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.7
#   return f(*args, **kwds)

# %%
tf.__version__
# Out:
# '1.11.0'

# %%
# !python -m pip install --upgrade https://storage.googleapis.com/tensorflow/mac/cpu/tensorflow-1.14.0-py3-none-any.whl
# Out:
# Collecting tensorflow==1.14.0
#   Downloading https://storage.googleapis.com/tensorflow/mac/cpu/tensorflow-1.14.0-py3-none-any.whl (105.8MB)
#      |████████████████████████████████| 105.8MB 11.5MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: google-pasta>=0.1.6 in /Users/ayush/anaconda3/lib/python3.7/site-packages (from tensorflow==1.14.0) (0.1.7)
# Requirement already satisfied, skipping upgrade: grpcio>=1.8.6 in /Users/ayush/anaconda3/lib/python3.7/site-packages (from tensorflow==1.14.0) (1.23.0)
# Requirement already satisfied, skipping upgrade: keras-preprocessing>=1.0.5 in /Users/ayush/anaconda3/lib/python3.7/site-packages (from tensorflow==1.14.0) (1.1.0)
# Requirement already satisfied, skipping upgrade: termcolor>=1.1.0 in /Users/ayush/anaconda3/lib/python3.7/site-packages (from tensorflow==1.14.0) (1.1.0)
# Collecting tensorboard<1.15.0,>=1.14.0
#   Using cached https://files.pythonhosted.org/packages/91/2d/2ed263449a078cd9c8a9ba50ebd50123adf1f8cfbea1492f9084169b89d9/tensorboard-1.14.0-py3-none-any.whl
# Requirement already satisfied, skipping upgrade: tensorflow-estimator<1.15.0rc0,>=1.14.0rc0 in /Users/ayush/anaconda3/lib/python3.7/site-packages (from tensorflow==1.14.0) (1.14.0)
# Requirement already satisfied, skipping upgrade: numpy<2.0,>=1.14.5 in /Users/ayush/anaconda3/lib/python3.7/site-packages (from tensorflow==1.14.0) (1.14.5)
# Requirement already satisfied, skipping upgrade: wrapt>=1.11.1 in /Users/ayush/anaconda3/lib/python3.7/site-packages (from tensorflow==1.14.0) (1.11.2)
# Requirement already satisfied, skipping upgrade: astor>=0.6.0 in /Users/ayush/anaconda3/lib/python3.7/site-packages (from tensorflow==1.14.0) (0.8.0)
# Requirement already satisfied, skipping upgrade: gast>=0.2.0 in /Users/ayush/anaconda3/lib/python3.7/site-packages (from tensorflow==1.14.0) (0.3.2)
# Requirement already satisfied, skipping upgrade: keras-applications>=1.0.6 in /Users/ayush/anaconda3/lib/python3.7/site-packages (from tensorflow==1.14.0) (1.0.8)
# Requirement already satisfied, skipping upgrade: protobuf>=3.6.1 in /Users/ayush/anaconda3/lib/python3.7/site-packages (from tensorflow==1.14.0) (3.9.1)
# Requirement already satisfied, skipping upgrade: wheel>=0.26 in /Users/ayush/anaconda3/lib/python3.7/site-packages (from tensorflow==1.14.0) (0.33.6)
# Requirement already satisfied, skipping upgrade: absl-py>=0.7.0 in /Users/ayush/anaconda3/lib/python3.7/site-packages (from tensorflow==1.14.0) (0.8.0)
# Requirement already satisfied, skipping upgrade: six>=1.10.0 in /Users/ayush/anaconda3/lib/python3.7/site-packages (from tensorflow==1.14.0) (1.12.0)
# Requirement already satisfied, skipping upgrade: werkzeug>=0.11.15 in /Users/ayush/anaconda3/lib/python3.7/site-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14.0) (0.16.0)
# Requirement already satisfied, skipping upgrade: markdown>=2.6.8 in /Users/ayush/anaconda3/lib/python3.7/site-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14.0) (3.1.1)
# Collecting setuptools>=41.0.0
#   Using cached https://files.pythonhosted.org/packages/54/28/c45d8b54c1339f9644b87663945e54a8503cfef59cf0f65b3ff5dd17cf64/setuptools-42.0.2-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: h5py in /Users/ayush/anaconda3/lib/python3.7/site-packages (from keras-applications>=1.0.6->tensorflow==1.14.0) (2.9.0)
# Installing collected packages: setuptools, tensorboard, tensorflow
#   Found existing installation: setuptools 39.1.0
#     Uninstalling setuptools-39.1.0:
#       Successfully uninstalled setuptools-39.1.0
#   Found existing installation: tensorboard 1.10.0
#     Uninstalling tensorboard-1.10.0:
#       Successfully uninstalled tensorboard-1.10.0
#   Found existing installation: tensorflow 1.10.0
#     Uninstalling tensorflow-1.10.0:
#       Successfully uninstalled tensorflow-1.10.0
# Successfully installed setuptools-42.0.2 tensorboard-1.14.0 tensorflow-1.14.0

# %%
# !pip install numpy --upgrade
# Out:
# Collecting numpy
#   Downloading https://files.pythonhosted.org/packages/f0/14/f71a89e03578084111e352f464d9f3b7f701ebbecbd1a60e89c96983ef77/numpy-1.18.0-cp37-cp37m-macosx_10_9_x86_64.whl (15.1MB)
#      |████████████████████████████████| 15.1MB 2.1MB/s eta 0:00:01
# Installing collected packages: numpy
# Successfully installed numpy-1.18.0

# %%
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-0aa0b027fcb6> in <module>
# ----> 1 import numpy as np
#
# ModuleNotFoundError: No module named 'numpy'
